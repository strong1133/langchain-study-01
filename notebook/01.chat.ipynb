# %%
### LLM 모델 기본 사용법과 프롬프트 전달방법 01

from langchain_ollama import ChatOllama

llm = ChatOllama(model="gemma4:e4b")

llm.invoke("안녕하세요")
llm.invoke("대한민국의 수도는?")
# Out:
# AIMessage(content='안녕하세요! 😊 만나서 반갑습니다.\n\n혹시 저에게 궁금한 점이 있으신가요? 아니면 어떤 도움을 드릴까요? 편하게 말씀해주세요!', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-07-19T05:43:33.08738Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1561773958, 'load_duration': 332805042, 'prompt_eval_count': 17, 'prompt_eval_duration': 173072000, 'eval_count': 35, 'eval_duration': 1053779000, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019f78e6-adc0-7643-80b0-a462dc679f0d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 17, 'output_tokens': 35, 'total_tokens': 52})
