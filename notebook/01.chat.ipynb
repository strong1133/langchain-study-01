# %%
from  dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
### LLM 모델 기본 사용법과 프롬프트 전달방법 01
### Ollama 로컬 모델 사용

from langchain_ollama import ChatOllama

llm = ChatOllama(model="gemma4:e4b")

llm.invoke("안녕하세요")
llm.invoke("대한민국의 수도는?")
# Out:
# AIMessage(content='대한민국의 수도는 **서울**입니다.', additional_kwargs={}, response_metadata={'model': 'gemma4:e4b', 'created_at': '2026-07-19T06:04:42.232337Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4694739541, 'load_duration': 383040291, 'prompt_eval_count': 22, 'prompt_eval_duration': 163476000, 'eval_count': 137, 'eval_duration': 4134734999, 'logprobs': None, 'model_name': 'gemma4:e4b', 'model_provider': 'ollama'}, id='lc_run--019f78f9-ff11-7881-abb5-6ae05cfc68a3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 137, 'total_tokens': 159})

# %%
### LLM 모델 기본 사용법과 프롬프트 전달방법 01-01
### GPT API 사용

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

llm.invoke("안녕하세요")
llm.invoke("대한민국의 수도는?")
# Out:
# AIMessage(content='대한민국의 수도는 서울입니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 13, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_73ac716e3e', 'id': 'chatcmpl-E3EtQbAheojgcwIts4un3vyGkKoMq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f78f7-e3b3-7de2-ad44-6b1925aab5c1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 8, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
